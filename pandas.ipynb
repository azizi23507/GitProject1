# %% [markdown]
# # Pandas
# Pandas is a Python library used for working with data sets.<br>
# It has functions for analyzing, cleaning, exploring, and manipulating data.<br>
# The name "Pandas" has a reference to both "Panel Data", and "Python Data Analysis"

# %%
import pandas as pd

# %% [markdown]
# ### Series in Pandas
# A Pandas Series is like a column in a table.<br>
# It is a one-dimensional array holding data of any type.

# %%
arr = [1,5,7]
var = pd.Series(arr)
print(var)
print(var[0]) # return the first value of the Series
# Out:
# 0    1
# 1    5
# 2    7
# dtype: int64
# 1

# %% [markdown]
# ### Labels
# If nothing else is specified, the values are labeled with their index number. First value has index 0, second value has index 1 etc.<br>
# This label can be used to access a specified value.

# %%
# with index argument, we can name our own labels.
a = [1, 3, 5]
var = pd.Series(a, index=["x", "y", "z"])
print(var)
print(var["y"])
# Out:
# x    1
# y    3
# z    5
# dtype: int64
# 3

# %%
# we can also use key/value object like a dictionary when creating the series.
calories = {"day1": 420, "day2": 380, "day3": 390}
var = pd.Series(calories)
print(var)
print()
print(pd.Series(calories, index=["day1", "day3"])) # to select some of the items
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64
#
# day1    420
# day3    390
# dtype: int64

# %% [markdown]
# ### DataFrames
# A Pandas DataFrame is a 2 dimensional data structure, like a 2 dimensional array, or a table with rows and columns.<br>
# Data sets in Pandas are usually multi-dimensional tables, called DataFrames.<br>
# Series is like a column, a DataFrame is the whole table.

# %%
my_dataset = {
    "cars": ["BMW", "Volvo", "Ford"],
    "passings": [3, 7, 2]
}

my_var = pd.DataFrame(my_dataset)
print(my_var)
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2

# %%
# use the loc attribute to return one or more specified rows.
print(my_var.loc[0])
print()
# use a list of indices
print(my_var.loc[[0,1]])
# Out:
# cars        BMW
# passings      3
# Name: 0, dtype: object
#
#     cars  passings
# 0    BMW         3
# 1  Volvo         7

# %%
# with the index argument, we can name our own indices
df =pd.DataFrame(my_dataset, index=["day1", "day2", "day3"])
print(df)
print()
# use the named index in the loc attribute to return the specified row
print(df.loc["day1"])
print()
print(df.loc[["day2", "day3"]])
# Out:
#        cars  passings
# day1    BMW         3
# day2  Volvo         7
# day3   Ford         2
#
# cars        BMW
# passings      3
# Name: day1, dtype: object
#
#        cars  passings
# day2  Volvo         7
# day3   Ford         2

# %% [markdown]
# ### Pandas read CSV

# %%
df = pd.read_csv("advertising.csv")
print(df)
# Out:
#      nums     TV  radio Sppendings, M$  newspaper  sales
# 0       1  230.1                  37.8       69.2   22.1
# 1       2   44.5                  39.3       45.1   10.4
# 2       3   17.2                  45.9       69.3    9.3
# 3       4  151.5                  41.3       58.5   18.5
# 4       5  180.8                  10.8       58.4   12.9
# ..    ...    ...                   ...        ...    ...
# 195   196   38.2                   3.7       13.8    7.6
# 196   197   94.2                   4.9        8.1    9.7
# 197   198  177.0                   9.3        6.4   12.8
# 198   199  283.6                  42.0       66.2   25.5
# 199   200  232.1                   8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
print(df.to_string())
# Out:
#      nums     TV  radio Sppendings, M$  newspaper  sales
# 0       1  230.1                  37.8       69.2   22.1
# 1       2   44.5                  39.3       45.1   10.4
# 2       3   17.2                  45.9       69.3    9.3
# 3       4  151.5                  41.3       58.5   18.5
# 4       5  180.8                  10.8       58.4   12.9
# 5       6    8.7                  48.9       75.0    7.2
# 6       7   57.5                  32.8       23.5   11.8
# 7       8  120.2                  19.6       11.6   13.2
# 8       9    8.6                   2.1        1.0    4.8
# 9      10  199.8                   2.6       21.2   10.6
# 10     11   66.1                   5.8       24.2    8.6
# 11     12  214.7                  24.0        4.0   17.4
# 12     13   23.8                  35.1       65.9    9.2
# 13     14   97.5                   7.6        7.2    9.7
# 14     15  204.1                  32.9       46.0   19.0
# ...

# %% [markdown]
# ### read JSON

# %%
df = pd.read_json("text.json")
print(df)
# Out:
#                     user_id              email            name given_name  \
# 0  583c3ac3f38e84297c002546      test@test.com   test@test.com      Hello
# 1  583c5484cb79a5fe593425a9     test1@test.com  test1@test.com     Hello1
# 2  583c57672c7686377d2f66c9        aaa@aaa.com     aaa@aaa.com       John
# 3  5840b954da0529cd293d76fe            a@a.com         a@a.com       Jane
# 4  584a9d13e808bcf75f05f580  test9999@test.com             NaN      Dummy
#
#   family_name nickname        last_ip  logins_count  \
# 0        Test     test  94.121.163.63          15.0
# 1       Test1    test1  94.121.168.53           1.0
# 2       Dough      aaa  94.121.168.53           2.0
# 3       Dough        a  94.121.163.63           3.0
# 4        User      NaN            NaN           NaN
#
#                         created_at                       updated_at  \
# 0 2016-11-28 14:10:11.338000+00:00 2016-12-02 01:17:29.310000+00:00
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   user_id         5 non-null      str
#  1   email           5 non-null      str
#  2   name            4 non-null      str
#  3   given_name      5 non-null      str
#  4   family_name     5 non-null      str
#  5   nickname        4 non-null      str
#  6   last_ip         4 non-null      str
#  7   logins_count    4 non-null      float64
#  8   created_at      5 non-null      datetime64[us, UTC]
#  9   updated_at      5 non-null      datetime64[us, UTC]
#  10  last_login      4 non-null      str
#  11  email_verified  5 non-null      bool
# dtypes: bool(1), datetime64[us, UTC](2), float64(1), str(8)
# memory usage: 577.0 bytes
# None

# %% [markdown]
# ### Data Cleaning
# Data cleaning means fixing bad data in your data set.
#
# Bad data could be:
#
# - Empty cells
# - Data in wrong format
# - Wrong data
# - Duplicates
#
# In this tutorial you will learn how to deal with all of them.

# %%
print(pd.read_csv("data.csv").to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
# remove rows that has empty cells
print(pd.read_csv("data.csv").dropna().to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# 22         60    130       101     300.0
# ...

# %%
# By default, the dropna() method returns a new DataFrame, and will not change the original.
# to change the original DataFrame, use the inplace = True argument. dropna(inplace = True)

df = pd.read_csv('data.csv')
df.dropna(inplace = True)
print(df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# 22         60    130       101     300.0
# ...

# %%
# replace the Empty values
df = pd.read_csv("data.csv")
df.fillna(120, inplace=True)
print(df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112     120.0
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
# Replace for only specified columns
df = pd.read_csv('data.csv')
df.fillna({"Calories": 128}, inplace=True)
print(df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112     128.0
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...
